# %% [markdown]
# <a href="https://colab.research.google.com/github/TimWang318/numerical-analysis/blob/main/%E7%A9%8D%E5%88%86.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install matplotlib numpy

# %%
import matplotlib.pyplot as plt
import numpy as np
def mid(f,a,b,n):
  x = np.linspace(a,b,n+1)
  h = float((b-a)/n)
  s = 0.0
  for i in range(n):
    mk = float((x[i+1]+x[i])/2)
    s += f(mk)
  ans=s*h
  return ans

def f(x):
  return x**2

a=0
b=1

x_vals = np.arange(5, 200, 1)
error_vals = []
anns_vals = []
for ii in x_vals:
  anss = mid(lambda x:f(x),a,b,ii)
  error = (1/3)-anss
  error_vals.append(error)
  anns_vals.append(anss)

print(anss)
plt.plot(x_vals, error_vals, color='blue', label='error')
plt.xlabel("n (number of intervals)")
plt.ylabel("Error")
plt.title("Midpoint Rule Error for ∫x² dx")
plt.grid(True)
plt.legend()
plt.show()


plt.loglog(x_vals, np.abs(error_vals), color='red', marker='*', label='Error (log-log)')
plt.xlabel("n (number of intervals)")
plt.ylabel("Absolute Error")
plt.title("Midpoint Rule Error on log-log scale")
plt.grid(True, which="both", linestyle="--")
plt.legend()
plt.show()
# Out:
# 0.3333312290093684
